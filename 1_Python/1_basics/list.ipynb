# %%
l1=[1,2,3]
l2=[-1,-2,-3]

l3=l1 + l2
l3
# Out:
# [1, 2, 3, -1, -2, -3]

# %%
# zip function
l1=[1,2,3]
l2=[-1,-2,-3]

list(zip(l1,l2))
# Out:
# [(1, -1), (2, -2), (3, -3)]

# %%
[i+j for i,j in zip(l1,l2)]
# Out:
# [0, 0, 0]

# %%
# Out:
# 15
