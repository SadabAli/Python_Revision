# %%
d={'name':'sadab','age':'2','status':'Bhadwaaa'}
d
# Out:
# {'name': 'sadab', 'age': '2', 'status': 'Bhadwaaa'}

# %%
# items/key/values
print(d)
print(d.items()) # used to split keys and values
print(d.keys())
print(d.values())
# Out:
# {'name': 'sadab', 'age': '2', 'status': 'Bhadwaaa'}
# dict_items([('name', 'sadab'), ('age', '2'), ('status', 'Bhadwaaa')])
# dict_keys(['name', 'age', 'status'])
# dict_values(['sadab', '2', 'Bhadwaaa'])
