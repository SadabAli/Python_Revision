# %%
print('sadab')
# Out:
# sadab

# %% [markdown]
# aggrigation means has a relation (A School has Teachers.)

# %%
class Customer:
    def __init__(self,name,age,address):
        self.name=name
        self.age=age
        self.address=address

    def display_address(self):
        print(self.address.pin, self.address.state)

class Adderss:
    def __init__(self,pin,state):
        self.pin=pin
        self.state=state

add=Adderss(221211,'odisha')
cus=Customer('sadab',21,add)


cus.display_address()
# Out:
# 221211 odisha

# %% [markdown]
# lets's for edit profile

# %%
class Customer:
    def __init__(self,name,age,address):
        self.name=name
        self.age=age
        self.address=address

    def display_address(self):
        print(self.name, self.age, self.address.pin, self.address.state)


    def edit_profile(self,new_name,new_age,new_pin,new_state):
        self.name= new_name
        self.age = new_age
        self.address.edit_address(new_pin,new_state)

class Adderss:
    def __init__(self,pin,state):
        self.pin=pin
        self.state=state

    def edit_address(self,new_pin,new_state):
        self.pin=new_pin
        self.state=new_state

add=Adderss(221211,'odisha')
cus=Customer('sadab',21,add)


cus.display_address()

cus.edit_profile('simpal',21,1111,'maharastra')
cus.display_address()
# Out:
# sadab 21 221211 odisha
# simpal 21 1111 maharastra
