# %%
print("simpal")
# Out:
# simpal

# %%
# Inheritance

class User:
    def __init__(self):
        self.name = 'simpal'
    def login(self):
        print("Inside the login method")

class Student(User):
    def __init__(self):
        self.roll=220301120242
    def registration(self):
        print("registerd into the course")

# %%
u=User()
s=Student()

# %%
s.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 s.name
#
# AttributeError: 'Student' object has no attribute 'name'

# %% [markdown]
# if in child class has a counstructer, the compiler only run the child constructor & not move to the paren cunstructor

# %%
# Inheritance

class User:
    def __init__(self):
        self.name = 'simpal'
    def login(self):
        print("Inside the login method")

class Student(User):
    # def __init__(self):
    #     self.roll=220301120242
    def registration(self):
        print("registerd into the course")

u=User()
s=Student()
print(s.name)
s.login()
# Out:
# simpal
# Inside the login method

# %%
# child constructor

class User:
    def __init__(self,name,roll):
        self.name = name
        self.roll=roll
        print('Inside the parent class')
    

class Student(User):
    def __init__(self,gender):
        self.gender=gender
    print("Inside the child class")


s=Student('male')
# Out:
# Inside the child class

# %%
# child can't access private attribute and methods

# attributes

class User:
    def __init__(self):
        self.name = 'simpal'
        self.__roll=220301120242
        
    

class Student(User):
    def display(self):
        print(self.__roll)
    


s=Student()
print(s.name) # non-private attributes
s.display() # private attributes
# Out:
# simpal
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 20
#      18 s=Student()
#      19 print(s.name) # non-private attributes
# ---> 20 s.display() # private attributes
#
# Cell In[18], line 14, in Student.display(self)
#      13 def display(self):
# ---> 14     print(self.__roll)
#
# AttributeError: 'Student' object has no attribute '_Student__roll'

# %%
# child can't access private attribute and methods

# methods

class User:
    def __init__(self):
        self.name = 'simpal'
        self.__roll=220301120242
    def __show(self):
        print("i am batman")
        
    

class Student(User):
    def display(self):
        print(self.__roll)
    


s=Student()
print(s.name) # non-private attributes
s.show() # private attributes
# Out:
# simpal
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 22
#      20 s=Student()
#      21 print(s.name) # non-private attributes
# ---> 22 s.show() # private attributes
#
# AttributeError: 'Student' object has no attribute 'show'

# %%
# method overriding

class User:
    def __init__(self):
        self.name='simpal'
    def buy(self):
        print('Inside the parent class')

class Student(User):
    def buy(self):
        print('Inside child class')
s=Student()
s.buy()
# Out:
# Inside child class

# %% [markdown]
# cahee baap bole Dr. banne ke liye lekin beta Eng. banega!!!!!!!!

# %%
# Super

class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")
        # syntax to call parent ka buy method
        super().buy()

s=SmartPhone(20000, "Apple", 13)

s.buy()
# Out:
# Inside phone constructor
# Buying a smartphone
# Buying a phone

# %%
# why we use supersuper
# super keyword is always used inside the child class
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

class SmartPhone(Phone):
    def __init__(self, price, brand, camera, os, ram):
        print('Inside smartphone constructor')
        super().__init__(price, brand, camera)
        self.os = os
        self.ram = ram
        print ("Inside smartphone constructor")

s=SmartPhone(20000, "Samsung", 12, "Android", 2)

print(s.os)
print(s.brand)
# Out:
# Inside smartphone constructor
# Inside phone constructor
# Inside smartphone constructor
# Android
# Samsung

# %%
# practice
class Parent:

    def __init__(self,num):
      self.__num=num

    def get_num(self):
      return self.__num

class Child(Parent):
  
    def __init__(self,num,val):
      super().__init__(num)
      self.__val=val

    def get_val(self):
      return self.__val
      
son=Child(100,200)
print(son.get_num())
print(son.get_val())

# %%
class Parent:
    def __init__(self):
        self.num=100

class Child(Parent):

    def __init__(self):
        super().__init__()
        self.var=200
        
    def show(self):
        print(self.num)
        print(self.var)

son=Child()
son.show()

# %%
class Parent:
    def __init__(self):
        self.__num=100

    def show(self):
        print("Parent:",self.__num)

class Child(Parent):
    def __init__(self):
        super().__init__()
        self.__var=10

    def show(self):
        print("Child:",self.__var)

obj=Child()
obj.show()

# %% [markdown]
# ### Types of Inheritance
#
# - Single Inheritance
# - Multilevel Inheritance
# - Hierarchical Inheritance
# - Multiple Inheritance(Diamond Problem)
# - Hybrid Inheritance

# %%
# single inheritance
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass

SmartPhone(1000,"Apple","13px").buy()
# Out:
# Inside phone constructor
# Buying a phone

# %%
# multilevel
class Product:
    def review(self):
        print ("Product customer review")

class Phone(Product):
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass

s=SmartPhone(20000, "Apple", 12)

s.buy()
s.review()
# Out:
# Inside phone constructor
# Buying a phone
# Product customer review

# %%
# Hierarchical
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass

class FeaturePhone(Phone):
    pass

SmartPhone(1000,"Apple","13px").buy()
FeaturePhone(10,"Lava","1px").buy()
# Out:
# Inside phone constructor
# Buying a phone
# Inside phone constructor
# Buying a phone

# %%
# Multiple
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class Product:
    def review(self):
        print ("Customer review")

class SmartPhone(Phone, Product):
    pass

s=SmartPhone(20000, "Apple", 12)

s.buy()
s.review()
# Out:
# Inside phone constructor
# Buying a phone
# Customer review

# %%
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class Product:
    def buy(self):
        print ("Product buy method")

# Method resolution order
class SmartPhone(Phone,Product):
    pass

s=SmartPhone(20000, "Apple", 12)

s.buy()
# Out:
# Inside phone constructor
# Buying a phone

# %%
# practice
class A:

    def m1(self):
        return 20

class B(A):

    def m1(self):
        return 30

    def m2(self):
        return 40

class C(B):
  
    def m2(self):
        return 20
obj1=A()
obj2=B()
obj3=C()
print(obj1.m1() + obj3.m1()+ obj3.m2())

# %%
# run on python tutor
class A:

    def m1(self):
        return 20

class B(A):

    def m1(self):
        val=super().m1()+30
        return val

class C(B):
  
    def m1(self):
        val=self.m1()+20
        return val
obj=C()
# print(obj.m1())
