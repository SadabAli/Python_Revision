# %%
print('simpal')
# Out:
# simpal

# %%
for i in range(3):
    print('*',end="")
# Out:
# ***

# %%
for j in range(3):
    for i in range(3):
        print('*',end="")
    print()
# Out:
# ***
# ***
# ***

# %%
for j in range(3):
    for i in range(3):
        print('*',end="")
    print(end="\n")
# Out:
# ***
# ***
# ***
