# %%
print('sasad')
# Out:
# sasad

# %%
def square(number):
    return number ** 2
def queue(number):
    return number ** 3

def num(funct,number):
    return funct(number)

num(square,2)
# Out:
# 4
